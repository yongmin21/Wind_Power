# %%
import os
import pandas as pd
import glob

base_dir1 = '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_mse'
base_dir2 = '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1'

csv_files1 = glob.glob(os.path.join(base_dir1, '**', '*.csv'), recursive=True)
csv_files2 = glob.glob(os.path.join(base_dir2, '**', '*.csv'), recursive=True)

# %% [markdown]
# # gj power pred score

# %%
# total results (mse loss)
mse_result_df = []

for csv_file in csv_files1:
    df = pd.read_csv(csv_file)
    
    min_val_row = df.loc[df['Val Loss'].idxmin()] 
    model_name = os.path.basename(os.path.dirname(csv_file))
    
    mse_result_df.append({
        'model_name': model_name,
        'min_val_loss': min_val_row['Val Loss'],
        'MAE': min_val_row['MAE'],
        'gj_NMAE' : min_val_row['MAE']/20700,
        'yg_NMAE' : min_val_row['MAE']/79600,
        'criterion' : 'MSE'
    })

mse_result_df = pd.DataFrame(mse_result_df)

# %%
mse_result_df.sort_values(by='MAE').head()
# Out:
#                    model_name  min_val_loss        MAE   gj_NMAE   yg_NMAE  \
# 4     cluster_only_GRU256_3_z  1.644665e+07  2928.4126  0.141469  0.036789
# 6   cluster_3_only_GRU256_3_z  1.636774e+07  2938.1260  0.141938  0.036911
# 24  cluster_2_only_GRU256_3_z  1.624137e+07  2940.1401  0.142036  0.036936
# 17  cluster_5_only_GRU256_3_z  1.606313e+07  2951.4133  0.142580  0.037078
# 7   cluster_6_only_GRU256_3_z  1.596244e+07  2968.7075  0.143416  0.037295
#
#    criterion
# 4        MSE
# 6        MSE
# 24       MSE
# 17       MSE
# 7        MSE

# %%
smothL1_result_df = []

for csv_file in csv_files2:
    df = pd.read_csv(csv_file)
    
    min_val_row = df.loc[df['Val Loss'].idxmin()] 
    model_name = os.path.basename(os.path.dirname(csv_file))
    
    smothL1_result_df.append({
        'model_name': model_name,
        'min_val_loss': min_val_row['Val Loss'],
        'MAE': min_val_row['MAE'],
        'gj_NMAE' : min_val_row['MAE']/20700,
        'yg_NMAE' : min_val_row['MAE']/79600,
        'criterion' : 'SmoothL1'
    })

smothL1_result_df = pd.DataFrame(smothL1_result_df)

smothL1_result_df.sort_values(by='MAE').head()
# Out:
#                           model_name  min_val_loss        MAE   gj_NMAE  \
# 4         pca_and_cluster_GRU256_3_z   2878.514595  2879.0142  0.139083
# 7          cluster_6_only_GRU256_3_z   2881.707765  2882.2078  0.139237
# 2   medoid_cluster_3_only_GRU256_3_z   2892.986949  2893.4868  0.139782
# 10  medoid_cluster_2_only_GRU256_3_z   2893.539833  2894.0398  0.139809
# 3            cluster_only_GRU256_3_z   2899.382190  2899.8820  0.140091
#
#      yg_NMAE criterion
# 4   0.036169  SmoothL1
# 7   0.036209  SmoothL1
# 2   0.036350  SmoothL1
# 10  0.036357  SmoothL1
# 3   0.036431  SmoothL1

# %%
base_dir = '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu'

csv_files = glob.glob(os.path.join(base_dir, '**', '*.csv'), recursive=True)

smothL1_result_df = []

for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    
    min_val_row = df.loc[df['Val Loss'].idxmin()] 
    model_name = os.path.basename(os.path.dirname(csv_file))
    
    smothL1_result_df.append({
        'model_name': model_name,
        'min_val_loss': min_val_row['Val Loss'],
        'MAE': min_val_row['MAE'],
        'gj_NMAE' : min_val_row['MAE']/20700,
        'yg_NMAE' : min_val_row['MAE']/79600,
        'criterion' : 'SmoothL1'
    })

smothL1_result_df = pd.DataFrame(smothL1_result_df)

smothL1_result_df.sort_values(by='MAE').head()
# Out:
#                           model_name  min_val_loss        MAE   gj_NMAE  \
# 19  medoid_cluster_6_only_GRU256_3_z   2881.090865  2881.5908  0.139207
# 7   medoid_cluster_4_only_GRU256_3_z   2881.255077  2881.7546  0.139215
# 3         pca_and_cluster_GRU256_3_z   2882.827614  2883.3274  0.139291
# 16         cluster_2_only_GRU256_3_z   2884.959267  2885.4592  0.139394
# 13         cluster_5_only_GRU256_3_z   2884.998563  2885.4983  0.139396
#
#      yg_NMAE criterion
# 19  0.036201  SmoothL1
# 7   0.036203  SmoothL1
# 3   0.036223  SmoothL1
# 16  0.036249  SmoothL1
# 13  0.036250  SmoothL1

# %%
smothL1_result_df.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_111398/2160669718.py in ?()
# ----> 1 smothL1_result_df.clear()
#
# ~/anaconda3/envs/windPower/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'clear'

# %%
base_dir = '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400'

csv_files = glob.glob(os.path.join(base_dir, '**', '*.csv'), recursive=True)

print(csv_files)
smothL1_result_df = []

for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    
    min_val_row = df.loc[df['Val Loss'].idxmin()] 
    model_name = os.path.basename(os.path.dirname(csv_file))
    
    smothL1_result_df.append({
        'model_name': model_name,
        'min_val_loss': min_val_row['Val Loss'],
        'MAE': min_val_row['MAE'],
        'gj_NMAE' : min_val_row['MAE']/20700,
        'yg_NMAE' : min_val_row['MAE']/79600,
        'criterion' : 'SmoothL1',
        'path' : csv_file[50:]
    })

smothL1_result_df = pd.DataFrame(smothL1_result_df)

smothL1_result_df.sort_values(by='MAE')
# Out:
# ['/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/pca_only_GRU256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_3_only_GRU256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_5_only_LSTM256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_only_LSTM256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_only_LSTM256_3_z/pca_and_cluster_GRU256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_3_only_LSTM256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_5_only_GRU256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/pca_only_LSTM256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_2_only_GRU256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_4_only_LSTM256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/pca_and_cluster_LSTM256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_4_only_GRU256_3_z/training_log.csv', '/home/user/Wind_Power/notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_2_only_LSTM256_3_z/training_log.csv']
#                      model_name  min_val_loss        MAE   gj_NMAE   yg_NMAE  \
# 4    pca_and_cluster_GRU256_3_z   2864.934944  2865.4350  0.138427  0.035998
# 0           pca_only_GRU256_3_z   2904.304217  2904.8040  0.140329  0.036493
# 1     cluster_3_only_GRU256_3_z   2904.831677  2905.3313  0.140354  0.036499
# 8     cluster_2_only_GRU256_3_z   2929.062796  2929.5627  0.141525  0.036804
# 6     cluster_5_only_GRU256_3_z   2946.056099  2946.5560  0.142346  0.037017
# 11    cluster_4_only_GRU256_3_z   2956.444257  2956.9440  0.142848  0.037148
# 7          pca_only_LSTM256_3_z   3714.885937  3715.3850  0.179487  0.046676
# 2    cluster_5_only_LSTM256_3_z   3717.580983  3718.0796  0.179617  0.046710
# 10  pca_and_cluster_LSTM256_3_z   3781.171940  3781.6711  0.182689  0.047508
# 12   cluster_2_only_LSTM256_3_z   3835.173565  3835.6729  0.185298  0.048187
# 9    cluster_4_only_LSTM256_3_z   3880.790835  3881.2900  0.187502  0.048760
# 3      cluster_only_LSTM256_3_z   6568.388754  6568.8555  0.317336  0.082523
# 5    cluster_3_only_LSTM256_3_z   6568.388754  6568.8555  0.317336  0.082523
#
#    criterion                                               path
# 4   SmoothL1  nal_smoothL1_useRelu400/cluster_only_LSTM256_3...
# 0   SmoothL1  nal_smoothL1_useRelu400/pca_only_GRU256_3_z/tr...
# 1   SmoothL1  nal_smoothL1_useRelu400/cluster_3_only_GRU256_...
# 8   SmoothL1  nal_smoothL1_useRelu400/cluster_2_only_GRU256_...
# 6   SmoothL1  nal_smoothL1_useRelu400/cluster_5_only_GRU256_...
# 11  SmoothL1  nal_smoothL1_useRelu400/cluster_4_only_GRU256_...
# 7   SmoothL1  nal_smoothL1_useRelu400/pca_only_LSTM256_3_z/t...
# 2   SmoothL1  nal_smoothL1_useRelu400/cluster_5_only_LSTM256...
# 10  SmoothL1  nal_smoothL1_useRelu400/pca_and_cluster_LSTM25...
# 12  SmoothL1  nal_smoothL1_useRelu400/cluster_2_only_LSTM256...
# 9   SmoothL1  nal_smoothL1_useRelu400/cluster_4_only_LSTM256...
# 3   SmoothL1  nal_smoothL1_useRelu400/cluster_only_LSTM256_3...
# 5   SmoothL1  nal_smoothL1_useRelu400/cluster_3_only_LSTM256...

# %% [markdown]
# # yg power pred score

# %%
# total results yg smoothL1
base_dir3 = '/home/user/Wind_Power/notebooks/yg/TEST_bidirectional_smoothL1'
csv_files3 = glob.glob(os.path.join(base_dir3, '**', '*.csv'), recursive=True)
smothL1_result_df = []

for csv_file in csv_files3:
    df = pd.read_csv(csv_file)
    
    min_val_row = df.loc[df['Val Loss'].idxmin()] 
    model_name = os.path.basename(os.path.dirname(csv_file))
    
    smothL1_result_df.append({
        'model_name': model_name,
        'min_val_loss': min_val_row['Val Loss'],
        'MAE': min_val_row['MAE'],
        'gj_NMAE' : min_val_row['MAE']/20700,
        'yg_NMAE' : min_val_row['MAE']/79600,
        'criterion' : 'SmoothL1'
    })

smothL1_result_df = pd.DataFrame(smothL1_result_df)

smothL1_result_df.sort_values(by='MAE').head()
# Out:
#                    model_name  min_val_loss        MAE   gj_NMAE   yg_NMAE  \
# 0     cluster_only_GRU256_3_z   3457.272762  3457.7695  0.167042  0.043439
# 5    kmedoids_only_GRU256_3_z   3473.679725  3474.1760  0.167835  0.043645
# 1  pca_and_cluster_GRU256_3_z   3515.288171  3515.7870  0.169845  0.044168
# 4   kmedoids_only_LSTM256_3_z   3712.365352  3712.8618  0.179365  0.046644
# 2    cluster_only_LSTM256_3_z   3747.253910  3747.7532  0.181051  0.047082
#
#   criterion
# 0  SmoothL1
# 5  SmoothL1
# 1  SmoothL1
# 4  SmoothL1
# 2  SmoothL1

# %%
# total results yg smoothL1
base_dir3 = '/home/user/Wind_Power/notebooks/yg/TEST_bidirectional_smoothL1_useRelu'
csv_files3 = glob.glob(os.path.join(base_dir3, '**', '*.csv'), recursive=True)
smothL1_result_df = []

for csv_file in csv_files3:
    df = pd.read_csv(csv_file)
    
    min_val_row = df.loc[df['Val Loss'].idxmin()] 
    model_name = os.path.basename(os.path.dirname(csv_file))
    
    smothL1_result_df.append({
        'model_name': model_name,
        'min_val_loss': min_val_row['Val Loss'],
        'MAE': min_val_row['MAE'],
        'gj_NMAE' : min_val_row['MAE']/20700,
        'yg_NMAE' : min_val_row['MAE']/79600,
        'criterion' : 'SmoothL1'
    })

smothL1_result_df = pd.DataFrame(smothL1_result_df)

smothL1_result_df.sort_values(by='MAE').head()
# Out:
#                           model_name  min_val_loss        MAE   gj_NMAE  \
# 2   medoid_cluster_3_only_GRU256_3_z   3418.534620  3419.0344  0.165171
# 5          cluster_3_only_GRU256_3_z   3419.712242  3420.2122  0.165228
# 17         cluster_2_only_GRU256_3_z   3441.956610  3442.4563  0.166302
# 14         cluster_5_only_GRU256_3_z   3442.460190  3442.9602  0.166327
# 24         cluster_4_only_GRU256_3_z   3446.792198  3447.2922  0.166536
#
#      yg_NMAE criterion
# 2   0.042953  SmoothL1
# 5   0.042967  SmoothL1
# 17  0.043247  SmoothL1
# 14  0.043253  SmoothL1
# 24  0.043308  SmoothL1

# %%
# total results yg smoothL1
base_dir3 = '/home/user/Wind_Power/notebooks/yg/TEST_bidirectional_smoothL1_useRelu400'
csv_files3 = glob.glob(os.path.join(base_dir3, '**', '*.csv'), recursive=True)
smothL1_result_df = []

for csv_file in csv_files3:
    df = pd.read_csv(csv_file)
    
    min_val_row = df.loc[df['Val Loss'].idxmin()] 
    model_name = os.path.basename(os.path.dirname(csv_file))
    
    smothL1_result_df.append({
        'model_name': model_name,
        'min_val_loss': min_val_row['Val Loss'],
        'MAE': min_val_row['MAE'],
        'gj_NMAE' : min_val_row['MAE']/20700,
        'yg_NMAE' : min_val_row['MAE']/79600,
        'criterion' : 'SmoothL1'
    })

smothL1_result_df = pd.DataFrame(smothL1_result_df)

smothL1_result_df.sort_values(by='MAE')
# Out:
#                      model_name  min_val_loss        MAE   gj_NMAE   yg_NMAE  \
# 9   pca_and_cluster_LSTM256_3_z   3078.492482  3078.9927  0.148744  0.038681
# 4      cluster_only_LSTM256_3_z   3079.218461  3079.7183  0.148779  0.038690
# 6          pca_only_LSTM256_3_z   3094.651837  3095.1516  0.149524  0.038884
# 8    cluster_4_only_LSTM256_3_z   3105.325418  3105.8254  0.150040  0.039018
# 11   cluster_2_only_LSTM256_3_z   3115.251496  3115.7512  0.150519  0.039143
# 5    cluster_3_only_LSTM256_3_z   3119.140888  3119.6404  0.150707  0.039191
# 3     cluster_3_only_GRU256_3_z   3439.867864  3440.3677  0.166201  0.043221
# 1       cluster_only_GRU256_3_z   3458.764953  3459.2650  0.167114  0.043458
# 10    cluster_4_only_GRU256_3_z   3484.121509  3484.6216  0.168339  0.043777
# 7     cluster_2_only_GRU256_3_z   3497.211042  3497.7107  0.168972  0.043941
# 0           pca_only_GRU256_3_z   3523.760496  3524.2603  0.170254  0.044275
# 2    pca_and_cluster_GRU256_3_z   3549.414207  3549.9140  0.171493  0.044597
#
#    criterion
# 9   SmoothL1
# 4   SmoothL1
# 6   SmoothL1
# 8   SmoothL1
# 11  SmoothL1
# 5   SmoothL1
# 3   SmoothL1
# 1   SmoothL1
# 10  SmoothL1
# 7   SmoothL1
# 0   SmoothL1
# 2   SmoothL1

# %% [markdown]
# # make submission

# %% [markdown]
# ## avg data Experiment result

# %% [markdown]
# ### load and pre processing

# %%
import warnings
import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearnex import patch_sklearn, config_context
patch_sklearn()
warnings.filterwarnings('ignore')

import os
ipynb_path = os.getcwd()
src_path = os.path.join(ipynb_path, 'src/')
input_path = os.path.join(ipynb_path,"input/")


import warnings
import os
import sys

import scipy.stats as spst

sys.path.append(src_path)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import dask
import dask.dataframe as dd
from windpowerlib.wind_speed import logarithmic_profile
from src.utils import uv_to_wsd # 윈도우에서는 앞에 src를 뺄것

from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.model_selection import TimeSeriesSplit

# yongmin's functions
from src.utils import DataConnector
from src.metric import NMAE
from src.data_processor import *

# model import
import xgboost as xgb
from xgboost import XGBRegressor
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
#y = pd.read_parquet(input_path + "train_y.parquet").rename({'end_datetime': 'dt'}, axis=1)
gj_ldaps = pd.read_parquet(input_path + "test_ldaps_gyeongju.parquet")
yg_ldaps = pd.read_parquet(input_path + "test_ldaps_yeonggwang.parquet")
# 파이프라인 구성 및 적용
gj_DataPipeline = Pipeline([
    ('uv_transform', UVTransformer('wind_u_10m', 'wind_v_10m')),
    ('wind_transform', WindTransformer('wind_speed', 10, 100, gj_ldaps['surf_rough'].mean())),
    ('feature_engineering', FeatureTransformer()),
])
yg_DataPipeline = Pipeline([
    ('uv_transform', UVTransformer('wind_u_10m', 'wind_v_10m')),
    ('wind_transform', WindTransformer('wind_speed', 10, 100, gj_ldaps['surf_rough'].mean())),
    ('feature_engineering', FeatureTransformer()),
])

# 파이프라인을 이용하여 ldaps 데이터 변환
gj_ldaps_transformed = gj_DataPipeline.fit_transform(gj_ldaps)
yg_ldaps_transformed = yg_DataPipeline.fit_transform(yg_ldaps)

print(gj_ldaps_transformed.shape)
print(yg_ldaps_transformed.shape)
# Out:
# (78840, 23)
# (306600, 23)

# %%
gj_average_ldaps = gj_ldaps_transformed.drop('turbine_id', axis=1).groupby('dt').mean()
gj_average_ldaps.columns = gj_average_ldaps.columns.str.replace(r'[<>\[\]]', '_', regex=True)
gj_average_ldaps.columns = gj_average_ldaps.columns.str.replace(r'[^\w]', '_', regex=True)
gj_average_ldaps.columns = gj_average_ldaps.columns.str.replace(r'__+', '_', regex=True)

gj_average_ldaps.reset_index(inplace=True)

yg_average_ldaps = yg_ldaps_transformed.drop('turbine_id', axis=1).groupby('dt').mean()
yg_average_ldaps.columns = yg_average_ldaps.columns.str.replace(r'[<>\[\]]', '_', regex=True)
yg_average_ldaps.columns = yg_average_ldaps.columns.str.replace(r'[^\w]', '_', regex=True)
yg_average_ldaps.columns = yg_average_ldaps.columns.str.replace(r'__+', '_', regex=True)

yg_average_ldaps.reset_index(inplace=True)


yg_average_ldaps['dt'] = pd.to_datetime(yg_average_ldaps['dt']).dt.tz_localize(None)

gj_average_ldaps['dt'] = pd.to_datetime(gj_average_ldaps['dt']).dt.tz_localize(None)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler


avg_data_sorted = yg_average_ldaps.sort_values(['dt'], ascending=[True])
avg_data_cleaned = avg_data_sorted.drop_duplicates(subset=['dt'], keep='first')

avg_data_cleaned = yg_average_ldaps.drop_duplicates(subset=['dt'], keep='first')
avg_data = avg_data_cleaned
numeric_columns = avg_data.select_dtypes(include=['number']).columns.tolist()

yg_x = avg_data[numeric_columns]

z_scaler = StandardScaler()
yg_x_z = z_scaler.fit_transform(yg_x)
yg_x_z = pd.DataFrame(yg_x_z, columns=yg_x.columns)

minmax_scaler = MinMaxScaler()
yg_x_m = minmax_scaler.fit_transform(yg_x)
yg_x_m = pd.DataFrame(yg_x_m, columns=yg_x.columns)

# %%
gj_data_sorted = gj_average_ldaps.sort_values(['dt'], ascending=[True])
gj_data_cleaned = gj_data_sorted.drop_duplicates(subset=['dt'], keep='first')

gj_data_cleaned = gj_average_ldaps.drop_duplicates(subset=['dt'], keep='first')
gj_data = gj_data_cleaned
numeric_columns = gj_data.select_dtypes(include=['number']).columns.tolist()

gj_x = gj_data[numeric_columns]

z_scaler = StandardScaler()
gj_x_z = z_scaler.fit_transform(gj_x)
gj_x_z = pd.DataFrame(gj_x_z, columns=gj_x.columns)

minmax_scaler = MinMaxScaler()
gj_x_m = minmax_scaler.fit_transform(gj_x)
gj_x_m = pd.DataFrame(gj_x_m, columns=gj_x.columns)

# %%
from sklearn.cluster import KMeans

# KMeans 특징 추가 (테스트 데이터만 적용)
def addKmeansFeature(test_data):
    #print(test_data)
    pd.options.mode.chained_assignment = None  # 경고 무시

    # 3차원 데이터를 2차원으로 변환
    if len(test_data.shape) == 3:
        test_data = test_data.reshape(-1, test_data.shape[-1])  # (2, 26202, 26)을 (52404, 26)으로 변환
    
    test_data = pd.DataFrame(test_data)  # 2차원으로 변환 후 DataFrame으로 변환

    for n_clusters in range(2, 7):  # 2부터 6까지 클러스터 생성
        kmeans = KMeans(n_clusters=n_clusters, n_init=10)
        
        # 테스트 데이터에 클러스터링 결과 추가
        test_data[f'cluster_{n_clusters}'] = kmeans.fit_predict(test_data[['wind_speed', 'wind_direction']])

    return test_data

# PCA와 KMedoids 함수들도 같은 방식으로 수정
from sklearn.decomposition import PCA

def addPCAFeature(test_data):
    #print(test_data)
    # 3차원 데이터를 2차원으로 변환
    if len(test_data.shape) == 3:
        test_data = test_data.reshape(-1, test_data.shape[-1])  # (2, 26202, 26)을 (52404, 26)으로 변환

    test_data = pd.DataFrame(test_data)  # 2차원으로 변환 후 DataFrame으로 변환
    
    # PCA 적용할 특징 열 선택
    wind_features = ['storm_u_5m', 'storm_v_5m', 'wind_u_10m', 'wind_v_10m', 
                     'wind_speed', 'wind_direction']
    
    # PCA 모델 생성 (훈련 데이터에서 학습되었다고 가정)
    pca = PCA(n_components=2)
    
    # 테스트 데이터에 PCA 적용
    pca_test = pca.fit_transform(test_data[wind_features])
    test_data['PC1'] = pca_test[:, 0]
    test_data['PC2'] = pca_test[:, 1]

    return test_data

#gj_x_z.head()

# 이 함수를 사용하여 호출
gj_x_z = addKmeansFeature(gj_x_z)
gj_x_z = addPCAFeature(gj_x_z)
print('gj_x_z에 KMeans, PCA, KMedoids 적용 완료')

yg_x_z = addKmeansFeature(yg_x_z)
yg_x_z = addPCAFeature(yg_x_z)
print('yg_x_z에 KMeans, PCA, KMedoids 적용 완료')
# Out:
# gj_x_z에 KMeans, PCA, KMedoids 적용 완료
# yg_x_z에 KMeans, PCA, KMedoids 적용 완료

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### lstm, gru

# %%
import torch
from torch import nn

class LSTMModule(nn.Module):
    
    def __init__(self, input_dim, hidden_dim, rec_dropout=0.4, num_layers=1, bidirectional=False):
        super(LSTMModule, self).__init__()
        self.rnn = nn.LSTM(input_dim, hidden_dim, bidirectional=bidirectional, batch_first=True,
                           dropout=rec_dropout, num_layers=num_layers)

    def save(self, filename):
        torch.save(self.state_dict(), filename)

    def load(self, filename=None, parameters=None):
        if filename is not None:
            self.load_state_dict(torch.load(filename))
        elif parameters is not None:
            self.load_state_dict(parameters)
        else:
            raise NotImplementedError("load is a filename or a list of parameters (state_dict)")

    def forward(self, x):
        recurrent, _ = self.rnn(x)
        return recurrent

class GRUModule(nn.Module):
    def __init__(self, input_dim, hidden_dim, rec_dropout=0.4, num_layers=1, bidirectional=False):
        super(GRUModule, self).__init__()
        self.rnn = nn.GRU(input_dim, hidden_dim, bidirectional=bidirectional, batch_first=True,
                          dropout=rec_dropout, num_layers=num_layers)

    def save(self, filename):
        torch.save(self.state_dict(), filename)

    def load(self, filename=None, parameters=None):
        if filename is not None:
            self.load_state_dict(torch.load(filename))
        elif parameters is not None:
            self.load_state_dict(parameters)
        else:
            raise NotImplementedError("load is a filename or a list of parameters (state_dict)")

    def forward(self, x):
        recurrent, _ = self.rnn(x)
        return recurrent

class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, rec_dropout=0.4, num_layers=1, bidirectional=False):
        super(LSTM, self).__init__()
        self.lstm_module = LSTMModule(input_dim, hidden_dim, rec_dropout, num_layers, bidirectional)
        self.bidirectional = bidirectional
        # Bidirectional 여부에 따른 fc1 크기 조정
        if self.bidirectional:
            self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        else:
            self.fc1 = nn.Linear(hidden_dim, hidden_dim // 2)
        
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        recurrent = self.lstm_module(x)
        out = self.fc1(recurrent)
        out = self.fc2(out)
        out = torch.clamp(out, min=0) # capacity write later
        return out


class GRU(nn.Module):
    def __init__(self, input_dim, hidden_dim, rec_dropout=0.4, num_layers=1, bidirectional=False):
        super(GRU, self).__init__()
        self.gru_module = GRUModule(input_dim, hidden_dim, rec_dropout, num_layers, bidirectional)
        self.bidirectional = bidirectional
        # Bidirectional 여부에 따른 fc1 크기 조정
        if self.bidirectional:
            self.fc1 = nn.Linear(hidden_dim * 2, hidden_dim)
        else:
            self.fc1 = nn.Linear(hidden_dim, hidden_dim // 2)
        
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        recurrent = self.gru_module(x)
        out = self.fc1(recurrent)
        out = self.fc2(out)
        out = torch.clamp(out, min=0) # capacity write later
        return out

# %% [markdown]
# #### lstm, gru (use relu)

# %%
class LSTM_relu(nn.Module):
    def __init__(self, input_dim, hidden_dim, rec_dropout=0.4, num_layers=1, bidirectional=False):
        super(LSTM_relu, self).__init__()
        self.lstm_module = LSTMModule(input_dim, hidden_dim, rec_dropout, num_layers, bidirectional)
        self.bidirectional = bidirectional
        if self.bidirectional:
            self.fc1 = nn.Sequential(
                nn.Linear(hidden_dim * 2, hidden_dim),
                nn.ReLU()
            )
        else:
            self.fc1 = nn.Sequential(
                nn.Linear(hidden_dim, hidden_dim // 2),
                nn.ReLU()
            )
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        recurrent = self.lstm_module(x)
        out = self.fc1(recurrent)
        out = self.fc2(out)
        # out = torch.clamp(out, min=0) # capacity write later
        return out


class GRU_relu(nn.Module):
    def __init__(self, input_dim, hidden_dim, rec_dropout=0.4, num_layers=1, bidirectional=False):
        super(GRU_relu, self).__init__()
        self.gru_module = GRUModule(input_dim, hidden_dim, rec_dropout, num_layers, bidirectional)
        self.bidirectional = bidirectional
        if self.bidirectional:
            self.fc1 = nn.Sequential(
                nn.Linear(hidden_dim * 2, hidden_dim),
                nn.ReLU()
            )
        else:
            self.fc1 = nn.Sequential(
                nn.Linear(hidden_dim, hidden_dim // 2),
                nn.ReLU()
            )
        self.fc2 = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        recurrent = self.gru_module(x)
        out = self.fc1(recurrent)
        out = self.fc2(out)
        # out = torch.clamp(out, min=0) # capacity write later
        return out

# %% [markdown]
# ### Predict

# %%
x_dict = {
    # 원본 데이터만 사용
    'original': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                 'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                 'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m'],

    # PCA 추가
    'pca_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                 'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                 'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'PC1', 'PC2'],

    # 클러스터(2~6) 추가
    'cluster_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                     'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                     'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 
                     'cluster_2', 'cluster_3', 'cluster_4', 'cluster_5', 'cluster_6'],

    # PCA + 클러스터(2~6) 추가
    'pca_and_cluster': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                        'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                        'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 
                        'PC1', 'PC2', 'cluster_2', 'cluster_3', 'cluster_4', 'cluster_5', 'cluster_6'],

    # 클러스터 개수에 따른 경우
    'cluster_2_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                       'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                       'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'cluster_2'],
    
    'cluster_3_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                       'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                       'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'cluster_3'],
    
    'cluster_4_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                       'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                       'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'cluster_4'],
    
    'cluster_5_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                       'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                       'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'cluster_5'],
    
    'cluster_6_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                       'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                       'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'cluster_6'],

    # KMedoids 추가
    'kmedoids_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                      'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                      'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 
                      'medoid_cluster_2', 'medoid_cluster_3', 'medoid_cluster_4', 'medoid_cluster_5', 'medoid_cluster_6'],

    # PCA + KMedoids 추가
    'pca_and_kmedoids': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                         'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                         'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 
                         'PC1', 'PC2', 'medoid_cluster_2', 'medoid_cluster_3', 'medoid_cluster_4', 'medoid_cluster_5', 'medoid_cluster_6'],

    # KMedoids 클러스터 개수에 따른 경우
    'medoid_cluster_2_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                              'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                              'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'medoid_cluster_2'],

    'medoid_cluster_3_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                              'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                              'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'medoid_cluster_3'],

    'medoid_cluster_4_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                              'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                              'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'medoid_cluster_4'],

    'medoid_cluster_5_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                              'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                              'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'medoid_cluster_5'],

    'medoid_cluster_6_only': ['elevation', 'land_cover', 'surf_rough', 'frictional_vmax_50m', 'frictional_vmin_50m', 
                              'pressure', 'relative_humid', 'specific_humid', 'temp_air', 'storm_u_5m', 'storm_v_5m', 
                              'wind_u_10m', 'wind_v_10m', 'wind_speed', 'wind_direction', 'wind_speed_100m', 'medoid_cluster_6']

}

# %%
# 저장된 모델 불러오기
model = GRU_relu(input_dim=gj_x_z[x_dict['pca_and_cluster']].shape[1], hidden_dim=400, num_layers=4, bidirectional=True) 
model.load_state_dict(torch.load('notebooks/gj/TEST_bidirectional_smoothL1_useRelu400/cluster_only_LSTM256_3_z/pca_and_cluster_GRU256_3_z/GRU_best_model.pth')) 
model.eval()

# 데이터 준비
input_data = torch.tensor(gj_x_z[x_dict['pca_and_cluster']].values, dtype=torch.float32)

# 예측 수행
with torch.no_grad():
    gj_predictions = model(input_data)

# %%
model = GRU_relu(input_dim=yg_x_z[x_dict['pca_and_cluster']].shape[1], hidden_dim=256, num_layers=4, bidirectional=True) 
model.load_state_dict(torch.load('notebooks/yg/TEST_bidirectional_smoothL1_useRelu400/pca_and_cluster_GRU256_3_z/GRU_best_model.pth')) 
model.eval()

# 데이터 준비
input_data = torch.tensor(yg_x_z[x_dict['pca_and_cluster']].values, dtype=torch.float32)

# 예측 수행
with torch.no_grad():
    yg_predictions = model(input_data)

# %%
input_data.shape
# Out:
# torch.Size([8760, 23])

# %%
plt.figure(figsize=(10, 6))
plt.plot(yg_predictions.numpy(), color="blue", label="pred")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### write
# # PLZ CHECK NO ERRORS IN PREDICTION PROCESS!!!!!

# %%
submision_df = pd.read_csv(input_path + "submission_format.csv", encoding='CP949')
submision_df.columns
# Out:
# Index(['plant_name', 'end_datetime', 'period_hours', 'energy_kwh'], dtype='object')

# %%
# '영광풍력'과 그 외의 마스크
yg_mask = submision_df['plant_name'] == '영광풍력'
gj_mask = submision_df['plant_name'] != '영광풍력'

# 텐서를 넘파이 배열로 변환
yg_predictions_np = yg_predictions.numpy()
gj_predictions_np = gj_predictions.numpy()

# '영광풍력' 마스크에 해당하는 행의 수와 yg_predictions_np의 길이 확인
if len(yg_predictions_np) == yg_mask.sum():
    submision_df.loc[yg_mask, 'energy_kwh'] = yg_predictions_np
else:
    raise ValueError(f"yg_predictions 길이({len(yg_predictions_np)})와 '영광풍력'에 해당하는 행 수({yg_mask.sum()})가 맞지 않습니다.")

# '영광풍력'이 아닌 마스크에 해당하는 행의 수와 gj_predictions_np의 길이 확인
if len(gj_predictions_np) == gj_mask.sum():
    submision_df.loc[gj_mask, 'energy_kwh'] = gj_predictions_np
else:
    raise ValueError(f"gj_predictions 길이({len(gj_predictions_np)})와 '영광풍력'이 아닌 행 수({gj_mask.sum()})가 맞지 않습니다.")

# 결과 확인
print(submision_df.head())
# Out:
#   plant_name               end_datetime  period_hours    energy_kwh
# 0       경주풍력  2023-01-01T01:00:00+09:00             1  17808.505859
# 1       경주풍력  2023-01-01T02:00:00+09:00             1  18011.529297
# 2       경주풍력  2023-01-01T03:00:00+09:00             1  17807.574219
# 3       경주풍력  2023-01-01T04:00:00+09:00             1  17648.917969
# 4       경주풍력  2023-01-01T05:00:00+09:00             1  17386.683594

# %%
submision_df.to_csv('씽씽 불어라팀 4차 중간평가 제출(모델3).csv', index=False, encoding='CP949')

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
yg_energy_kwh = submision_df.loc[yg_mask, 'energy_kwh']
plt.plot(yg_energy_kwh.values, label="submision_df['energy_kwh']", color='orange')
plt.title('yg_predictions')
plt.xlabel('Index')
plt.ylabel('Energy kWh')
plt.legend()

plt.subplot(1, 2, 2)
gj_energy_kwh = submision_df.loc[gj_mask, 'energy_kwh']
plt.plot(gj_energy_kwh.values, label="submision_df['energy_kwh']", color='orange')
plt.title('gj_predictions')
plt.xlabel('Index')
plt.ylabel('Energy kWh')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Additional Test

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler


def get_trasforms_datas(merged_data, numeric_columns, target):
    z_scaler = StandardScaler()
    minmax_scaler = MinMaxScaler()
    
    x_train = merged_data.loc[merged_data['dt'].between('2020-01-01', '2020-12-31', inclusive='left'), numeric_columns]
    x_test = merged_data.loc[merged_data['dt'].between('2021-01-01', '2022-12-31', inclusive='left'), numeric_columns]

    y_train = merged_data.loc[merged_data['dt'].between('2020-01-01', '2020-12-31', inclusive='left'), target]
    y_test = merged_data.loc[merged_data['dt'].between('2021-01-01', '2022-12-31', inclusive='left'), target]
    #y_train = y_train.dropna()
    #y_test = y_test.dropna()

    # Min-Max Scaling
    x_train_m = minmax_scaler.fit_transform(x_train)
    x_train_m = pd.DataFrame(x_train_m, columns=x_train.columns)
    x_test_m = minmax_scaler.transform(x_test)
    x_test_m = pd.DataFrame(x_test_m, columns=x_train.columns)

    # Standard Scaling
    x_train_z = z_scaler.fit_transform(x_train)
    x_train_z = pd.DataFrame(x_train_z, columns=x_train.columns)
    x_test_z = z_scaler.transform(x_test)
    x_test_z = pd.DataFrame(x_test_z, columns=x_train.columns)

    return x_train, x_test, x_train_m, x_test_m, x_train_z, x_test_z, y_train, y_test

# %%
yg_y = pd.read_parquet(input_path + "train_y.parquet").rename({'end_datetime': 'dt'}, axis=1)
ldaps = pd.read_parquet(input_path + "train_ldaps_yeonggwang.parquet")

print("train_y: ", yg_y.shape)
print("LDAPS: ", ldaps.shape)

# 파이프라인 구성 및 적용
DataPipeline = Pipeline([
    ('uv_transform', UVTransformer('wind_u_10m', 'wind_v_10m')),
    ('wind_transform', WindTransformer('wind_speed', 10, 100, ldaps['surf_rough'].mean())),
    ('feature_engineering', FeatureTransformer()),
])

# 파이프라인을 이용하여 ldaps 데이터 변환
ldaps_transformed = DataPipeline.fit_transform(ldaps)

print(ldaps_transformed.shape)


average_ldaps = ldaps_transformed.drop('turbine_id', axis=1).groupby('dt').mean()
average_ldaps.columns = average_ldaps.columns.str.replace(r'[<>\[\]]', '_', regex=True)
average_ldaps.columns = average_ldaps.columns.str.replace(r'[^\w]', '_', regex=True)
average_ldaps.columns = average_ldaps.columns.str.replace(r'__+', '_', regex=True)

average_ldaps.reset_index(inplace=True)


average_ldaps['dt'] = pd.to_datetime(average_ldaps['dt']).dt.tz_localize(None)
yg_y = yg_y.loc[yg_y['plant_name'] == '영광풍력']
#yg_y.head()
yg_y['dt'] = pd.to_datetime(yg_y['dt']).dt.tz_localize(None)
avg_data = pd.merge(average_ldaps, yg_y, on='dt', how='inner')
# Out:
# train_y:  (52608, 4)
# LDAPS:  (917070, 15)
# (917070, 23)

# %%
avg_data_sorted = avg_data.sort_values(['dt', 'plant_name', 'energy_kwh'], ascending=[True, True, False])
avg_data_cleaned = avg_data_sorted.drop_duplicates(subset=['dt', 'plant_name'], keep='first')

avg_data_cleaned = avg_data.drop_duplicates(subset=['dt'], keep='first')
avg_data = avg_data_cleaned
numeric_columns = avg_data.select_dtypes(include=['number']).columns.tolist()
x_train, x_test, x_train_m, x_test_m, x_train_z, x_test_z, y_train, y_test = get_trasforms_datas(avg_data, numeric_columns, 'energy_kwh')

# %%
from sklearn.cluster import KMeans

# 이제 특징 생성에 클러스터링 결과는 보지 않을 예정.
def addKmeansFeature(train_data, test_data):
    pd.options.mode.chained_assignment = None

    for n_clusters in range(2, 7):  # 2부터 6까지 클러스터 생성
        kmeans = KMeans(n_clusters=n_clusters, n_init=10)

        train_data[f'cluster_{n_clusters}'] = kmeans.fit_predict(train_data[['wind_speed', 'wind_direction']])
        
        test_data[f'cluster_{n_clusters}'] = kmeans.predict(test_data[['wind_speed', 'wind_direction']])

    return train_data, test_data
from sklearn.decomposition import PCA

def addPCAFeature(train_data, test_data):
    # PCA 적용할 특징 열 선택 (u, v 성분)
    wind_features = ['storm_u_5m', 'storm_v_5m', 'wind_u_10m', 'wind_v_10m', 
                     'wind_speed', 'wind_direction']
    
    # 훈련 데이터에서 PCA 학습
    pca = PCA(n_components=2)
    pca_train = pca.fit_transform(train_data[wind_features])
    
    # 훈련 데이터에 주성분 추가
    train_data['PC1'] = pca_train[:, 0]
    train_data['PC2'] = pca_train[:, 1]
    
    # 테스트 데이터에 PCA 적용
    pca_test = pca.transform(test_data[wind_features])
    test_data['PC1'] = pca_test[:, 0]
    test_data['PC2'] = pca_test[:, 1]

    # PCA 설명력 확인
    explained_variance = pca.explained_variance_ratio_
    print(f"PC1 설명력: {explained_variance[0]}")
    print(f"PC2 설명력: {explained_variance[1]}")

    return train_data, test_data

from sklearn_extra.cluster import KMedoids

def addKMedoidsFeature(train_data, test_data):
    pd.options.mode.chained_assignment = None

    for n_clusters in range(2, 7):  # 2부터 6까지 클러스터 생성
        kmedoids = KMedoids(n_clusters=n_clusters, random_state=42)

        # 훈련 데이터에 K-Medoids 클러스터링 적용
        train_data[f'medoid_cluster_{n_clusters}'] = kmedoids.fit_predict(train_data[['wind_speed', 'wind_direction']])

        # 테스트 데이터에 학습된 K-Medoids 모델 적용
        test_data[f'medoid_cluster_{n_clusters}'] = kmedoids.predict(test_data[['wind_speed', 'wind_direction']])

    return train_data, test_data

# %%
x_train, x_test = addKmeansFeature(x_train, x_test)
x_train_m, x_test_m = addKmeansFeature(x_train_m, x_test_m)
x_train_z, x_test_z = addKmeansFeature(x_train_z, x_test_z)
print('kmean 적용 완료')
x_train, x_test = addPCAFeature(x_train, x_test)
x_train_m, x_test_m = addPCAFeature(x_train_m, x_test_m)
x_train_z, x_test_z = addPCAFeature(x_train_z, x_test_z)
print('pca 적용 완료')

x_train, x_test = addKMedoidsFeature(x_train, x_test)
x_train_m, x_test_m = addKMedoidsFeature(x_train_m, x_test_m)
x_train_z, x_test_z = addKMedoidsFeature(x_train_z, x_test_z)
print('kmedoid 적용 완료')
# Out:
# kmean 적용 완료
# PC1 설명력: 0.9969626069068909
# PC2 설명력: 0.001954863080754876
# PC1 설명력: 0.7320484617797179
# PC2 설명력: 0.14104104431898426
# PC1 설명력: 0.46370585375874857
# PC2 설명력: 0.23818530022354453
# pca 적용 완료
# kmedoid 적용 완료

# %%
model = GRU_relu(input_dim=x_test[x_dict['pca_and_cluster']].shape[1], hidden_dim=256, num_layers=4, bidirectional=True) 
model.load_state_dict(torch.load('notebooks/yg/TEST_bidirectional_smoothL1_useRelu400/pca_and_cluster_GRU256_3_z/GRU_best_model.pth')) 
model.eval()

# 데이터 준비
input_data = torch.tensor(x_test[x_dict['pca_and_cluster']].values, dtype=torch.float32)

# 예측 수행
with torch.no_grad():
    yg_predictions = model(input_data)

# %%
input_data.shape
# Out:
# torch.Size([17418, 23])

# %%
plt.figure(figsize=(10, 6))
plt.plot(yg_predictions.numpy(), color="blue", label="pred")
#plt.plot(y_test.numpy(), color="orange", label="ground")

plt.legend()
plt.grid(True)
plt.show()
